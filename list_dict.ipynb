# %%
mydict = {10:"rahul"}

# %%
mydict={10:"mohan"}
mydict
# Out:
# {10: 'mohan'}

# %%
mydict[10] = "rsm"

# %%
mydict
# Out:
# {10: 'rsm'}

# %%
m={}
for i in "hello":
    m[i]=1

m
# Out:
# {'h': 1, 'e': 1, 'l': 1, 'o': 1}

# %%
count = 0
for i in "rahulbunker":
    count = count + 1

print(count)
# Out:
# 11

# %%
mydict ={"total": 0}
for i in "rahul":
    mydict["total"] = mydict["total"] + 1
mydict
# Out:
# {'total': 5}

# %%
v={}
c={}
for i in "hello my name is rahul":
    if i in "aeiou":
        if i in v:
            v[i] = v[i] +1
        else:
            v[i] = 1
    elif i not "aeiou":
        if i in c:
            c[i] = c[i] + i
# Out:
#   Cell In[3], line 9
#     elif i not "aeiou":
#                ^
# SyntaxError: invalid syntax

# %%
s="helo my name is rahul"
v=0
c=0
for i in s:
    if i in "aeiou":
        v=v+1
    else:
        c=c+1
print("vowels" , v)
print("consonate: ",c)
# Out:
# vowels 7
# consonate:  14

# %%
s="helo my name is rahul"
v=0
c=0
for i in s:
    if i.isalpha():
        if i in "aeiou":
            v=v+1
        else:
            c=c+1
print("vowels" , v)
print("consonate: ",c)
# Out:
# vowels 7
# consonate:  10

# %%
i=1
while(i<=5):
    i=i+1
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
i=1
while(i<=5):
    i=i+1
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
count = 0
total = 0
while(True):
    if count%2==0:
        print(count)
        total = total +1
    if total ==5:
        break
    count = count +1
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
m={}
for i in "hello":
    m[i]=1

m
# Out:
# {'h': 1, 'e': 1, 'l': 1, 'o': 1}

# %%
m.values()
# Out:
# dict_values([1, 1, 1, 1])

# %%
m.keys()
# Out:
# dict_keys(['h', 'e', 'l', 'o'])

# %%
m.items()
# Out:
# dict_items([('h', 1), ('e', 1), ('l', 1), ('o', 1)])

# %%
list(m.keys())
# Out:
# ['h', 'e', 'l', 'o']

# %%
len(m.keys())
# Out:
# 4

# %%
m.update({"h":"rahul"})

# %%
m
# Out:
# {'h': 'rahul', 'e': 1, 'l': 1, 'o': 1}

# %%
m={5:544}
m
# Out:
# {5: 544}

# %%
m
# Out:
# {5: 544}

# %%
m[10]=26655

# %%
m
# Out:
# {5: 544, 10: 26655}

# %%
m.get(10)
# Out:
# 26655

# %%
m[10]
# Out:
# 26655

# %%
# set

# %%
myset = {1,2,3,4,5,6,7,8,9}
myset
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
myset.add(25346)
myset
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 25346}

# %%
myset.update(["rahul",45])

# %%
myset
# Out:
# {1, 2, 25346, 3, 4, 45, 5, 6, 7, 8, 9, 'rahul'}

# %%
myset.remove(9)

# %%
myset
# Out:
# {1, 2, 25346, 3, 4, 45, 5, 6, 7, 8, 'rahul'}

# %%
myset.discard("rahul")
myset
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 45, 25346}

# %%
null_set = set()

# %%
null_set
# Out:
# set()

# %%
m
# Out:
# {5: 544, 10: 26655}

# %%
m.clear()

# %%
m
# Out:
# {}

# %%
marks = {}
hindi = int(input("enter the hindi markds :"))
eng = int(input("enter the eng marks :"))
sst = int(input("enter the sst markd :"))
marks["hindi"] = hindi
marks.update({"eng" :eng , "sst":sst})
marks
# Out:
# enter the hindi markds : 6
# enter the eng marks : 4
# enter the sst markd : 64
# {'hindi': 6, 'eng': 4, 'sst': 64}

# %%
values = {2,2.}
values
# Out:
# {2}

# %%
v = {2,"2."}
v
# Out:
# {2, '2.'}

# %%
v = {("f",2.) , ("int" ,2)}
v
# Out:
# {('f', 2.0), ('int', 2)}

# %%
m = [ "a" , "b" , "a" , "c" ,"d", "a"]
m.sort()

# %%
m
# Out:
# ['a', 'a', 'a', 'b', 'c', 'd']

# %%
m.count("a")
# Out:
# 3

# %%
list1 = [1,2,5,2,1,1]
list2 = [1,2,3,1]

copylist1 = list1.copy()
copylist2 = list1.reverse()
if(list1 == copylist1):
    print("pall")
else:
    print("not")
# Out:
# not

# %%
str = "i am 45 rahul"

# %%
str.endswith("rahul")
# Out:
# True

# %%
str.endswith("rahu")
# Out:
# False

# %%
str.capitalize()
# Out:
# 'I am rahul'

# %%
str.replace("rahul","jatin")
# Out:
# 'i am jatin'

# %%
str.find("jatin")
# Out:
# -1

# %%
str.find("am")
# Out:
# 2

# %%
str.find("i")
# Out:
# 0

# %%
str.count("a")
# Out:
# 2

# %%
str.startswith("i")
# Out:
# True

# %%
str.index("i")
# Out:
# 0

# %%
str.isalpha()
# Out:
# False

# %%
str.isdigit()
# Out:
# False

# %%
words = ["hello" , "i"]
print("*".join(words))
# Out:
# hello*i

# %%
text = "hbfk FDSVGFD"
text.swapcase()
# Out:
# 'HBFK fdsvgfd'
