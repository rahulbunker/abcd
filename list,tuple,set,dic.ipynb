# %%
print("hey","hello")
# Out:
# hey hello

# %%
y=''' ghvf hbh kj'''
x=10
x
y
# Out:
# ' ghvf hbh kj'

# %%
# string formating

# %%
c = "regex"
year =2026
print("compnay name is ",c ,"year is " , year )
# Out:
# compnay name is  regex year is  2026

# %%
print(f"compant name is {c} year is {year}")
# Out:
# compant name is regex year is 2026

# %%
# format method

# %%
print("comapany name is {1} year is {0}".format(c,year))
# Out:
# comapany name is 2026 year is regex

# %%
# list

# %%
marks  = [10,20,30]

# %%
marks[0]
# Out:
# 10

# %%
len(marks)
# Out:
# 3

# %%
marks.sort()

# %%
x =[10,5,60,6]
x.sort()

# %%
x
# Out:
# [5, 6, 10, 60]

# %%
y = x.sort(reverse=True)

# %%
print(y)
# Out:
# None

# %%
x
# Out:
# [60, 10, 6, 5]

# %%
x.insert(20,132)

# %%
x
# Out:
# [60, 10, 132, 6, 5, 132]

# %%
x.remove(5)

# %%
x
# Out:
# [60, 10, 132, 6, 132]

# %%
x.pop(1)
# Out:
# 10

# %%
x
# Out:
# [60, 132, 6, 132]

# %%
x.append(10)

# %%
x
# Out:
# [60, 132, 6, 132, 10, 10]

# %%
x.extend([10,20,"rahul"])

# %%
x
# Out:
# [60, 132, 6, 132, 10, 10, 10, 20, 'rahul', 10, 20, 'rahul']

# %%
x.extend("hey")

# %%
x
# Out:
# ['rahul', 2, 'gopal']

# %%
x=["rahul",2,"gopal"]
for i in x:
    if (type(i) is str):
        print(i , i[0]+i[-1])
# Out:
# rahul rl
# gopal gl

# %%
x=["rahul",2,"gopal"]
for i in x:
    if (type(i) is not str):
        print(i)
# Out:
# 2

# %%
# tuple

# %%
# this is immutubel

# %%
t = 10

# %%
type(t)
# Out:
# int

# %%
t = 10 ,20
type(t)
# Out:
# tuple

# %%
x
# Out:
# ['rahul', 2, 'gopal']

# %%
t[0]
# Out:
# 10

# %%
ind = x.index(2)
ind
# Out:
# 1

# %%
t1 =()

# %%
t2 = (10 ,20)

# %%
type(t2)
# Out:
# tuple

# %%
t2.count(10)
# Out:
# 1

# %%
a=input()
b=input()
c=input()
mylist =[]
mylist.append(a)
mylist.append(b)
mylist.append(c)

print(mylist)
# Out:
#  abc
#  race
#  rrr
# ['abc', 'race', 'rrr']

# %%
marks = ["a","b","b","c", "d", "e" , "g" ,"a" ,"a"]
marks.count("a")
# Out:
# 3

# %%
type(marks)
# Out:
# list

# %%
x=[5555,55,5555]
y=[1,2,3,2]

copy_x = x.copy()
copy_y = y.copy()

copy_x.reverse()
copy_y.reverse()

if(x == copy_x):
    print("pall")
else:
    print("not")
# Out:
# pall

# %%
 marks = [ 10,20,30,40,50,60]
new=[]
for i in marks:
    new.append(i*10)

print(new)
# Out:
# [100, 200, 300, 400, 500, 600]

# %%
 marks = [ 10,20,30,40,50,60]
new=[i+5 for i in marks]


print(new)
# Out:
# [15, 25, 35, 45, 55, 65]

# %%
cubes = []
for i in range(10):
    if(i%2==0):
        cubes.append(i**3)

cubes
# Out:
# [0, 8, 64, 216, 512]

# %%
cubes = [i**3 for i in range(10) if i%2==0]


cubes
# Out:
# [0, 8, 64, 216, 512]

# %%
s = { i**2  for i in range(10)}
s
# Out:
# {0, 1, 4, 9, 16, 25, 36, 49, 64, 81}

# %%
sq = {1:1 , 2:2 ,3:3}
sq2 = {i*10:i**2 for i in sq}
sq2
# Out:
# {10: 1, 20: 4, 30: 9}

# %%
# set

# %%
set ={120,10,20,10,23,10,2,2}
set
# Out:
# {2, 10, 20, 23, 120}

# %%
set.add(10000)
set
# Out:
# {2, 10, 20, 23, 120, 10000}

# %%
set.update(["rahul"])
set
# Out:
# {10, 10000, 120, 2, 20, 23, 'a', 'h', 'l', 'r', 'rahul', 'u'}

# %%
set.clear()
set
# Out:
# set()

# %%
di = { "hey" : ["hello" , "rahul"]}
di
# Out:
# {'hey': ['hello', 'rahul']}

# %%
# dictionary

# %%
x={10:"rahul" , 20:"gopal"}
x
# Out:
# {10: 'rahul', 20: 'gopal'}

# %%
x[30]="sohan"

# %%
x
# Out:
# {10: 'rahul', 20: 'gopal', 30: 'sohan'}

# %%
x.pop(30)
# Out:
# 'sohan'

# %%
x
# Out:
# {10: 'rahul', 20: 'gopal'}

# %%
dic = {}
for i in "djgfdfhdnxddsfndnbfdfbn":
    dic[i]=12

dic
# Out:
# {'d': 12,
#  'j': 12,
#  'g': 12,
#  'f': 12,
#  'h': 12,
#  'n': 12,
#  'x': 12,
#  's': 12,
#  'b': 12}

# %%
x={}
count=0
for i in "iamrahul":
    print(i)
    count=count+1
x["total"]=count
x
# Out:
# i
# a
# m
# r
# a
# h
# u
# l
# {'total': 8}

# %%
x
# Out:
# {}

# %%
x[1]=10

# %%
x
# Out:
# {1: 10}

# %%
x["total"]=10

# %%
x
# Out:
# {1: 10, 'total': 10}

# %%
x["total"]=count

# %%
x
# Out:
# {1: 10, 'total': 8}

# %%
xx={"total":0}
for i in "iamragul":
    xx["total"]=xx["total"]+1

xx
# Out:
# {'total': 8}

# %%
v={}
c={}
x="hellomynameisrahulhowareyou"
for i in x:
    if i in "aeiou":
        if i in v:
            v[i]=v[i]+1

        else:
            v[i]=1

    elif(i not in "aeiou"):
        if i in c:
            c[i]=c[i]+1
        else:
            c[i]=1

print(v)
print(c)
# Out:
# {'e': 3, 'o': 3, 'a': 3, 'i': 1, 'u': 2}
# {'h': 3, 'l': 3, 'm': 2, 'y': 2, 'n': 1, 's': 1, 'r': 2, 'w': 1}

# %%
v={}
c={}
x="hjs;lksdewesud"
for i in x:
    if i in "aeiou":
        if i in v:
            v[i]=v[i]+1
        else:
            v[i]=1
    elif( i not in "aeiou"):
        if i in c:
            c[i]=c[i]+1
        else:
            c[i]=1

print(v)
print(c)
# Out:
# {'e': 2, 'u': 1}
# {'h': 1, 'j': 1, 's': 3, ';': 1, 'l': 1, 'k': 1, 'd': 2, 'w': 1}

# %%
v.keys()
# Out:
# dict_keys(['e', 'u'])

# %%
v.values()
# Out:
# dict_values([2, 1])

# %%
c.items()
# Out:
# dict_items([('h', 1), ('j', 1), ('s', 3), (';', 1), ('l', 1), ('k', 1), ('d', 2), ('w', 1)])

# %%
c.get("h")
# Out:
# 1

# %%
c.update({1:354})

# %%
c
# Out:
# {'h': 1, 'j': 1, 's': 3, ';': 1, 'l': 1, 'k': 1, 'd': 2, 'w': 1, 1: 354}
